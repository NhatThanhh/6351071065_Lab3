# %%
# Câu a
from tensorflow.keras.datasets import mnist

print("Nguyễn Nhật Thanh - 6351071065")

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Câu b
print("Nguyễn Nhật Thanh - 6351071065")
print("Train shape:", train_images.shape)
print("Test shape:", test_images.shape)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %%
# Câu c
print("Nguyễn Nhật Thanh - 6351071065")
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %%
# Câu d
from sklearn.model_selection import train_test_split

print("Nguyễn Nhật Thanh - 6351071065")
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

print("New train images shape:", train_images.shape)
print("Validation images shape:", val_images.shape)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# New train images shape: (48000, 28, 28)
# Validation images shape: (12000, 28, 28)

# %%
# Câu e
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

print("Nguyễn Nhật Thanh - 6351071065")

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Câu f
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("Nguyễn Nhật Thanh - 6351071065")
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %%
# Câu g

print("Nguyễn Nhật Thanh - 6351071065")
history = model.fit(
    train_images, train_labels,
    epochs=5,
    batch_size=32,
    validation_data=(val_images, val_labels)
)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8461 - loss: 0.5325 - val_accuracy: 0.9502 - val_loss: 0.1722
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9513 - loss: 0.1657 - val_accuracy: 0.9628 - val_loss: 0.1253
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9639 - loss: 0.1184 - val_accuracy: 0.9717 - val_loss: 0.1007
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9713 - loss: 0.0962 - val_accuracy: 0.9741 - val_loss: 0.0892
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9750 - loss: 0.0786 - val_accuracy: 0.9749 - val_loss: 0.0855

# %%
# Câu h
import matplotlib.pyplot as plt

print("Nguyễn Nhật Thanh - 6351071065")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %%
# Câu i
import numpy as np

print("Nguyễn Nhật Thanh - 6351071065")

y_pred = model.predict(test_images)
y_pred_classes = np.argmax(predictions, axis=1)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(test_labels, y_pred_classes)
print(f"Accuracy của mô hình trên tập test: {accuracy:.4f}")

print("Nguyễn Nhật Thanh - 6351071065")
print(test_accuracy)
# Out:
# Accuracy của mô hình trên tập test: 0.9753
# Nguyễn Nhật Thanh - 6351071065
# 0.9753

# %%
# Câu k/
from sklearn.metrics import classification_report

print("Nguyễn Nhật Thanh - 6351071065")

print(classification_report(test_labels, predicted_classes))
# Out:
# Nguyễn Nhật Thanh - 6351071065
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       980
#            1       0.98      0.99      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.97      0.98      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.98      0.97      0.97       892
#            6       0.96      0.99      0.98       958
#            7       0.96      0.97      0.97      1028
#            8       0.97      0.97      0.97       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
# Câu l/
from sklearn.metrics import confusion_matrix
import seaborn as sns

print("Nguyễn Nhật Thanh - 6351071065")

cm = confusion_matrix(test_labels, predicted_classes)

plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %%
# Câu m

print("Nguyễn Nhật Thanh - 6351071065")
for i in range(5):
    image = test_images[i]
    img_expanded = np.expand_dims(image, axis=0)

    pred = np.argmax(model.predict(img_expanded))

    plt.imshow(image, cmap='gray')
    plt.title(f"Predicted: {pred} | True label: {test_labels[i]}")
    plt.axis('off')
    plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
# câu n
incorrect = []

for i in range(len(test_labels)):
    if y_pred_classes[i] != test_labels[i]:
        incorrect.append(i)
    if len(incorrect) == 5:
        break

for i in incorrect:
    plt.imshow(test_images[i], cmap='gray')
    plt.title(f"Predicted: {y_pred_classes[i]}, Actual: {test_labels[i]}")
    plt.show()

print("Nguyễn Nhật Thanh - 6351071065")
# Out:
# Nguyễn Nhật Thanh - 6351071065
