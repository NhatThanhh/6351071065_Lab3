# %% [markdown]
# **Câu a**

# %%
from sklearn.datasets import load_iris

iris = load_iris()
data = iris.data
target = iris.target
print("Nguyễn Nhật Thanh - 6351071065")
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %% [markdown]
# Câu **b**

# %%
import pandas as pd

print("Nguyễn Nhật Thanh - 6351071065")

print("Tên các thuộc tính:", iris.feature_names)
print("Tên các lớp phân loại:", iris.target_names)

print("Số lượng mẫu và số lượng thuộc tính:", data.shape)
print("Số lượng mẫu (target):", target.shape[0])

print("5 mẫu dữ liệu đầu tiên:")
print(data[:5])
print("5 nhãn mục tiêu đầu tiên:")
print(target[:5])

import pandas as pd

df = pd.DataFrame(data, columns=iris.feature_names)

df['target'] = target

print("Thống kê mô tả của bộ dữ liệu:")
print(df.describe())
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Tên các thuộc tính: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Tên các lớp phân loại: ['setosa' 'versicolor' 'virginica']
# Số lượng mẫu và số lượng thuộc tính: (150, 4)
# Số lượng mẫu (target): 150
# 5 mẫu dữ liệu đầu tiên:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# 5 nhãn mục tiêu đầu tiên:
# [0 0 0 0 0]
# Thống kê mô tả của bộ dữ liệu:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# ...

# %% [markdown]
# **Câu c**

# %%
import numpy as np

print("Nguyễn Nhật Thanh - 6351071065")

X = data
Y = target

X_normalized = X / np.max(X, axis=0)
print("5 mẫu dữ liệu đầu tiên sau khi chuẩn hóa:")
print(X_normalized[:5])
# Out:
# Nguyễn Nhật Thanh - 6351071065
# 5 mẫu dữ liệu đầu tiên sau khi chuẩn hóa:
# [[0.64556962 0.79545455 0.20289855 0.08      ]
#  [0.62025316 0.68181818 0.20289855 0.08      ]
#  [0.59493671 0.72727273 0.1884058  0.08      ]
#  [0.58227848 0.70454545 0.2173913  0.08      ]
#  [0.63291139 0.81818182 0.20289855 0.08      ]]

# %% [markdown]
# **Câu d**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, shuffle=True
)
print("Nguyễn Nhật Thanh - 6351071065")
# Out:
# Nguyễn Nhật Thanh - 6351071065

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print("Nguyễn Nhật Thanh - 6351071065")

X = data
Y = target
X_normalized = X / np.max(X, axis=0)

X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y, test_size=0.2, random_state=42)

clf = DecisionTreeClassifier(random_state=42)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy của mô hình trên tập test: {accuracy:.4f}")

report = classification_report(y_test, y_pred, target_names=iris.target_names)
print("Precision, Recall, F1-score của từng lớp:")
print(report)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.title("Confusion Matrix")
plt.xlabel("Dự đoán")
plt.ylabel("Thực tế")
plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Accuracy của mô hình trên tập test: 1.0000
# Precision, Recall, F1-score của từng lớp:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# **Câu f**

# %%
from sklearn.naive_bayes import GaussianNB

print("Nguyễn Nhật Thanh - 6351071065")

nb = GaussianNB()
nb.fit(X_train, y_train)

y_pred_nb = nb.predict(X_test)

print("Accuracy Naive Bayes:", accuracy_score(y_test, y_pred_nb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_nb))

cm = confusion_matrix(y_test, y_pred_nb)
sns.heatmap(cm, annot=True, cmap="Blues", fmt="g")
plt.title("Naive Bayes - Confusion Matrix")
plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Accuracy Naive Bayes: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# **Câu g**

# %%
from sklearn.neighbors import KNeighborsClassifier

print("Nguyễn Nhật Thanh - 6351071065")

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("Accuracy KNN:", accuracy_score(y_test, y_pred_knn))
print("\nClassification Report:\n", classification_report(y_test, y_pred_knn))

cm = confusion_matrix(y_test, y_pred_knn)
sns.heatmap(cm, annot=True, cmap="Blues", fmt="g")
plt.title("KNN - Confusion Matrix")
plt.show()
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Accuracy KNN: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# **Câu h**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(Dense(10, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(len(np.unique(Y)), activation='softmax'))

model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
print("Nguyễn Nhật Thanh - 6351071065")
history = model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3504 - loss: 1.1314
# Epoch 2/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7361 - loss: 0.9532
# Epoch 3/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8409 - loss: 0.7403
# Epoch 4/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9291 - loss: 0.5903
# Epoch 5/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.4517
# Epoch 6/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.3812
# Epoch 7/100
# ...

# %%
import numpy as np

print("Nguyễn Nhật Thanh - 6351071065")

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Accuracy của mô hình trên tập test: {accuracy:.4f}")

report = classification_report(y_test, y_pred_classes, target_names=iris.target_names)
print("Precision, Recall, F1-score của từng lớp:")
print(report)

cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=iris.target_names, yticklabels=iris.target_names)
# Out:
# Nguyễn Nhật Thanh - 6351071065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Accuracy của mô hình trên tập test: 0.9667
# Precision, Recall, F1-score của từng lớp:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      0.89      0.94         9
#    virginica       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30
# <Axes: >

# %% [markdown]
# **Câu i**

# %%
print("Nguyễn Nhật Thanh - 6351071065")

samples = np.array([
    [6.2, 2.9, 4.3, 1.3],
    [5.1, 3.5, 1.4, 0.2],
    [7.3, 2.8, 6.4, 2.1]
]).astype(float)

samples = samples / X.max(axis=0)

print("Decision Tree:", clf.predict(samples))
print("Naive Bayes:", nb.predict(samples))
print("KNN:", knn.predict(samples))
print("Neural Network:", np.argmax(model.predict(samples), axis=1))
# Out:
# Nguyễn Nhật Thanh - 6351071065
# Decision Tree: [1 0 2]
# Naive Bayes: [1 0 2]
# KNN: [1 0 2]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Neural Network: [1 0 2]

# %% [markdown]
# ### **Đánh giá hiệu suất các mô hình**
#
# #### **1. Decision Tree**
#
# * Mô hình đạt **Accuracy = 1.0**
# * Điều này cho thấy Decision Tree hoạt động rất tốt trong việc phân loại dữ liệu Iris, nơi các lớp phân tách rõ ràng.
# * Tuy nhiên, đối với các tập dữ liệu phức tạp hoặc kích thước lớn hơn, Decision Tree có thể gặp phải vấn đề **overfitting**, mặc dù trên bộ dữ liệu Iris không gặp phải vấn đề này.
#
# ---
#
# #### **2. Naive Bayes**
#
# * Mô hình đạt **Accuracy = 1.0**
# * Điều này phù hợp với giả định về phân phối Gaussian trong bộ dữ liệu Iris.
# * Naive Bayes có ưu điểm là **đơn giản và nhanh chóng**, rất hiệu quả trên các bộ dữ liệu nhỏ với các lớp phân tách rõ ràng như Iris.
#
# ---
#
# #### **3. K-Nearest Neighbors (KNN)**
#
# * Mô hình KNN đạt **Accuracy = 1.0**
# * KNN hoạt động tốt với các bài toán phân loại đơn giản như Iris, vì dữ liệu giữa các lớp tách biệt rất rõ ràng.
# * Tuy nhiên, KNN có thể gặp khó khăn khi dự đoán trên dữ liệu lớn do tốc độ tính toán chậm, nhưng đối với bộ dữ liệu nhỏ như Iris, điều này không phải là vấn đề lớn.
#
# ---
#
# #### **4. Neural Network (Keras)**
#
# * Mô hình Neural Network đạt **Accuracy = 0.97**.
# * Điều này chứng tỏ rằng Neural Network có thể học tốt trên bộ dữ liệu Iris với các lớp phân tách rõ ràng, mà không gặp phải hiện tượng underfitting hay overfitting.
# * Neural Network vẫn giữ được khả năng tổng quát hóa tốt và có thể áp dụng cho các bài toán phân loại phức tạp hơn.
#
# ---
#
# ### **Tổng kết**
#
# * **Các mô hình Decision Tree, Naive Bayes, KNN và Neural Network đều đạt hiệu suất gần như hoàn hảo trên tập dữ liệu Iris**, với kết quả đạt 100% trên ba mô hình đầu tiên và 97% trên Neural Network.
# * **Chọn mô hình tốt nhất cho Iris:**
#   → Các mô hình này có hiệu suất tương đương nhau trên bộ dữ liệu này. Có thể ưu tiên **Decision Tree, Naive Bayes** hoặc **KNN** nếu yêu cầu mô hình đơn giản, nhanh chóng, hoặc sử dụng **Neural Network** nếu muốn thử nghiệm với các phương pháp phức tạp hơn.
